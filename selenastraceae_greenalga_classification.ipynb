# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusrpb/cloud_image_classification/blob/main/selenastraceae_greenalga_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Dense,GlobalAveragePooling2D ,MaxPooling2D,Activation,Flatten,Conv2D,BatchNormalization,Dropout
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import SGD,Adam
from sklearn.model_selection import KFold, StratifiedKFold
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
import numpy as np
import pandas as pd
import tensorflow_addons as tfa

# %%
# !cp -r "/content/drive/My Drive/alga/alga_full" "alga_full"
path_data = "alga_full"

# %%
def get_model_name(sel_model,k):
    return sel_model+"_"+str(k)+'.h5'

# %%
def classification_model(sel_model,learning_rate,activation_f,num_labels,prob,number_of_neurons):

    f1_score = tfa.metrics.F1Score(num_classes=num_labels, average='macro',threshold=0.5)

    model = Sequential()

    if sel_model == 'resnet50':

        pre_trained_model = ResNet50(input_shape=(224,224,3),include_top=False,pooling ='avg',weights='imagenet', classes=num_labels)

        for layer in pre_trained_model.layers:
            layer.trainable = False

        model.add(pre_trained_model)

        model.add(GlobalAveragePooling2D())
        model.add(Flatten())
        model.add(Dense(number_of_neurons,activation="relu"))
        model.add(BatchNormalization())
        model.add(Dropout(prob))
        model.add(Dense(num_labels,activation=activation_f))

        # It is preferable to use SGD in combination to ResNet50

        sgd = SGD(learning_rate = 0.01, decay = 1e-6, momentum = 0.9, nesterov = True)

        model.compile(optimizer = SGD, 
              loss = 'categorical_crossentropy', 
              metrics = [f1_score])

    elif sel_model == 'vgg16':

        pre_trained_model = VGG16(input_shape=(224,224,3),include_top=False,pooling ='avg',weights='imagenet', classes=num_labels)

        for layer in pre_trained_model.layers:
            layer.trainable = False

        model.add(pre_trained_model)

        model.add(GlobalAveragePooling2D())
        model.add(Flatten())
        model.add(Dense(number_of_neurons,activation="relu"))
        model.add(BatchNormalization())
        model.add(Dropout(prob))
        model.add(Dense(num_labels,activation=activation_f))

        adams_family = Adam(learning_rate=learning_rate,decay=0.01)
        
        model.compile(optimizer = adams_family, 
              loss = 'categorical_crossentropy', 
              metrics = [f1_score])
    
    return model

# %% [markdown]
# Main function

# %% [markdown]
# Organize training and test sets

# %%
import os
list_subfolders = os.listdir(path_data)
    
list_subfolders.sort()

dataset_dict = {}

dataset_dict['filename'] = []
dataset_dict['label'] = []

for folder in list_subfolders:

    list_images_path = os.listdir(path_data+"/"+folder)
    
    list_images_path.sort()

    for image_name in list_images_path:

        dataset_dict['filename'].append(folder+"/"+image_name)

        dataset_dict['label'].append(folder)

# %%
df = pd.DataFrame.from_dict(dataset_dict)

# %%
df
# Out:
#                                     filename            label
# 0                      alga_full/ankisdensus        alga_full
# 1                  alga_full/ankisfusiformis        alga_full
# 2                     alga_full/kirchneriela        alga_full
# 3                 alga_full/monorapcontortum        alga_full
# 4                     alga_full/monorapgriff        alga_full
# ..                                       ...              ...
# 406    selenastrumbrib/JamariA_7dia_8_14.png  selenastrumbrib
# 407     selenastrumbrib/JamariA_7dia_8_2.png  selenastrumbrib
# 408     selenastrumbrib/JamariA_7dia_8_9.png  selenastrumbrib
# 409  selenastrumbrib/JamariA_7dia_8_orig.png  selenastrumbrib
# 410     selenastrumbrib/JamariA_7dia_9_4.png  selenastrumbrib
#
# [411 rows x 2 columns]

# %% [markdown]
# Define Stratified KFold

# %%
skf_outer = StratifiedKFold(n_splits = 10, random_state = 7, shuffle = True)

outer_results = list()

X = np.array(df['filename'])
y = np.array(df['label'])

num_labels = 8#len(y.unique)
sel_model = 'resnet55'
activation_f = 'softmax'
lr = 0.00001
epochs = 15
prob = 0.5
batch_size = 16
num_neurons = 256

f1_score = tfa.metrics.F1Score(num_classes=num_labels, average='macro',threshold=0.5)

agnostic_datagen = ImageDataGenerator(rescale=1./255)

# %%
test_f1score = []
test_fold = []
test_loss = []

trial = 1

for train_ix, test_ix in skf_outer.split(X,y):

    val_f1score = []
    val_loss = []
    
    train_list = []
    #y_train_list = []
    test_list = []

    for ind in train_ix:
        train_list.append([X[ind],y[ind]])
        #y_train_list.append(y[ind])
    
    for ind in test_ix:
        test_list.append([X[ind],y[ind]])

    X_train = pd.DataFrame(train_list, columns =['filename','label'])
    X_test = pd.DataFrame(test_list, columns =['filename','label'])

    test_generator = agnostic_datagen.flow_from_dataframe(X_test, directory = path_data,
							x_col = "filename", y_col = "label",
							class_mode = "categorical", shuffle = True)
    
    skf_inner = StratifiedKFold(n_splits = 10, random_state = 7, shuffle = True)

    nfold = 1

    for train_index, val_index in skf_inner.split(X_train['filename'],X_train['label']):
        
        train_list = []
        valid_list = []

        for ind in train_ix:
            train_list.append([X[ind],y[ind]])
        
        for ind in test_ix:
            valid_list.append([X[ind],y[ind]])

        X_train = pd.DataFrame(train_list, columns =['filename','label'])
        X_valid = pd.DataFrame(valid_list, columns =['filename','label'])


        train_generator = agnostic_datagen.flow_from_dataframe(X_train, directory = path_data,
                                                               x_col = "filename", y_col = "label",
                                                               class_mode = "categorical", shuffle = True)
        
        validation_generator = agnostic_datagen.flow_from_dataframe(X_valid, directory = path_data,
                                                                 x_col = "filename", y_col = "label",
                                                                 class_mode = "categorical", shuffle = True)
        
        #model = classification_model(sel_model,lr,activation_f,num_labels,prob,num_neurons)
        model = Sequential()
        pre_trained_model = VGG16(input_shape=(224,224,3),include_top=False,pooling ='avg',weights='imagenet', classes=num_labels)

        for layer in pre_trained_model.layers:
            layer.trainable = False

        model.add(pre_trained_model)

        #model.add(GlobalAveragePooling2D())
        model.add(Flatten())
        model.add(Dense(num_neurons,activation="relu"))
        model.add(BatchNormalization())
        model.add(Dropout(prob))
        model.add(Dense(num_labels,activation=activation_f))

        print(model.summary())
        
        fname = "weights-improvement-{epoch:02d}-{val_f1_score:.2f}.hdf5"
        
        checkpoint = ModelCheckpoint(fname, monitor='val_f1_score', verbose=1, save_best_only=True, mode='max')

        early_stopping = EarlyStopping(monitor='loss', patience=5)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.05, patience=5, min_lr=0.000002)
        callbacklist = [checkpoint,early_stopping,reduce_lr]

        adams_family = Adam(learning_rate=0.01,decay=0.01)
        
        model.compile(optimizer = adams_family, 
              loss = 'categorical_crossentropy', 
              metrics = [f1_score])

        history_fine = model.fit(train_generator,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=validation_generator,
                         callbacks=callbacklist
                         )
        
        f1 = history_fine.history['f1_score']
        val_f1 = history_fine.history['val_f1_score']

        loss = history_fine.history['loss']
        val_loss = history_fine.history['val_loss']

        val_f1score.append(np.mean(np.array(val_f1)))
        val_loss.append(np.mean(np.array(val_loss)))

        nfold+=1

        print(f'NFold {nfold} Validation loss: {val_loss} / Validation f-score: {val_f1}')
        #del model
    
        score = model.evaluate(test_generator,batch_size=batch_size) 
        print(f'Trial {trial} Test loss: {score[0]} / Test accuracy: {score[1]}\n')

        trial+=1

        test_f1score.append(np.mean(np.array(val_f1score)))
        test_loss.append(np.mean(np.array(val_loss)))

        del model
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=10.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 1 invalid image filename(s) in x_col="filename". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=10.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 7 invalid image filename(s) in x_col="filename". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 1 invalid image filename(s) in x_col="filename". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 41 validated image filenames belonging to 8 classes.
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_10 (Flatten)        (None, 512)               0
#
#  dense_20 (Dense)            (None, 256)               131328
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.3797 - f1_score: 0.4504
# Epoch 1: val_f1_score improved from -inf to 0.09375, saving model to weights-improvement-01-0.09.hdf5
# 12/12 [==============================] - 5s 321ms/step - loss: 1.3797 - f1_score: 0.4504 - val_loss: 1.4998 - val_f1_score: 0.0937 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6593 - f1_score: 0.7245
# Epoch 2: val_f1_score improved from 0.09375 to 0.16288, saving model to weights-improvement-02-0.16.hdf5
# 12/12 [==============================] - 3s 282ms/step - loss: 0.6593 - f1_score: 0.7245 - val_loss: 1.8884 - val_f1_score: 0.1629 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5567 - f1_score: 0.7461
# Epoch 3: val_f1_score did not improve from 0.16288
# 12/12 [==============================] - 3s 278ms/step - loss: 0.5567 - f1_score: 0.7461 - val_loss: 1.5152 - val_f1_score: 0.1539 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4355 - f1_score: 0.8185
# Epoch 4: val_f1_score improved from 0.16288 to 0.35283, saving model to weights-improvement-04-0.35.hdf5
# 12/12 [==============================] - 4s 291ms/step - loss: 0.4355 - f1_score: 0.8185 - val_loss: 1.1440 - val_f1_score: 0.3528 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4132 - f1_score: 0.8349
# Epoch 5: val_f1_score improved from 0.35283 to 0.38678, saving model to weights-improvement-05-0.39.hdf5
# 12/12 [==============================] - 3s 303ms/step - loss: 0.4132 - f1_score: 0.8349 - val_loss: 1.1374 - val_f1_score: 0.3868 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3178 - f1_score: 0.8675
# Epoch 6: val_f1_score did not improve from 0.38678
# 12/12 [==============================] - 3s 273ms/step - loss: 0.3178 - f1_score: 0.8675 - val_loss: 1.1719 - val_f1_score: 0.3056 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3034 - f1_score: 0.8868
# Epoch 7: val_f1_score improved from 0.38678 to 0.42532, saving model to weights-improvement-07-0.43.hdf5
# 12/12 [==============================] - 4s 291ms/step - loss: 0.3034 - f1_score: 0.8868 - val_loss: 0.9399 - val_f1_score: 0.4253 - lr: 0.0100
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2506 - f1_score: 0.9007
# Epoch 8: val_f1_score improved from 0.42532 to 0.68274, saving model to weights-improvement-08-0.68.hdf5
# 12/12 [==============================] - 4s 291ms/step - loss: 0.2506 - f1_score: 0.9007 - val_loss: 0.7725 - val_f1_score: 0.6827 - lr: 0.0100
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2369 - f1_score: 0.8972
# Epoch 9: val_f1_score did not improve from 0.68274
# 12/12 [==============================] - 3s 275ms/step - loss: 0.2369 - f1_score: 0.8972 - val_loss: 0.7231 - val_f1_score: 0.5444 - lr: 0.0100
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1723 - f1_score: 0.9451
# Epoch 10: val_f1_score did not improve from 0.68274
# 12/12 [==============================] - 3s 283ms/step - loss: 0.1723 - f1_score: 0.9451 - val_loss: 0.7393 - val_f1_score: 0.5259 - lr: 0.0100
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1789 - f1_score: 0.9348
# Epoch 11: val_f1_score improved from 0.68274 to 0.69766, saving model to weights-improvement-11-0.70.hdf5
# 12/12 [==============================] - 3s 279ms/step - loss: 0.1789 - f1_score: 0.9348 - val_loss: 0.6152 - val_f1_score: 0.6977 - lr: 0.0100
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1904 - f1_score: 0.9269
# Epoch 12: val_f1_score did not improve from 0.69766
# 12/12 [==============================] - 3s 272ms/step - loss: 0.1904 - f1_score: 0.9269 - val_loss: 0.7064 - val_f1_score: 0.5563 - lr: 0.0100
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1806 - f1_score: 0.9353
# Epoch 13: val_f1_score did not improve from 0.69766
# 12/12 [==============================] - 3s 267ms/step - loss: 0.1806 - f1_score: 0.9353 - val_loss: 0.6287 - val_f1_score: 0.6134 - lr: 0.0100
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1314 - f1_score: 0.9458
# Epoch 14: val_f1_score did not improve from 0.69766
# 12/12 [==============================] - 3s 268ms/step - loss: 0.1314 - f1_score: 0.9458 - val_loss: 0.5296 - val_f1_score: 0.6698 - lr: 0.0100
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1768 - f1_score: 0.9341
# Epoch 15: val_f1_score did not improve from 0.69766
# 12/12 [==============================] - 3s 272ms/step - loss: 0.1768 - f1_score: 0.9341 - val_loss: 0.6284 - val_f1_score: 0.6029 - lr: 0.0100
# NFold 2 Validation loss: [1.4998130798339844, 1.8883672952651978, 1.5152455568313599, 1.1440240144729614, 1.137413501739502, 1.1718868017196655, 0.939874529838562, 0.7724904417991638, 0.723109245300293, 0.739341139793396, 0.6152268648147583, 0.7063822150230408, 0.6287022233009338, 0.5295655727386475, 0.6283969283103943, 0.975989294052124] / Validation f-score: [0.0937499925494194, 0.16287879645824432, 0.15388257801532745, 0.35282808542251587, 0.3867788314819336, 0.3056451678276062, 0.4253205358982086, 0.6827381253242493, 0.5444444417953491, 0.5258928537368774, 0.6976641416549683, 0.5562500357627869, 0.6134262084960938, 0.669806718826294, 0.6029411554336548]
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6284 - f1_score: 0.6029
# Trial 1 Test loss: 0.6283968687057495 / Test accuracy: 0.6029411554336548
#
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_11 (Flatten)        (None, 512)               0
#
#  dense_22 (Dense)            (None, 256)               131328
#
#  batch_normalization_11 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.0996 - f1_score: 0.5533
# Epoch 1: val_f1_score improved from -inf to 0.17445, saving model to weights-improvement-01-0.17.hdf5
# 12/12 [==============================] - 5s 308ms/step - loss: 1.0996 - f1_score: 0.5533 - val_loss: 1.8531 - val_f1_score: 0.1745 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6749 - f1_score: 0.7037
# Epoch 2: val_f1_score improved from 0.17445 to 0.22532, saving model to weights-improvement-02-0.23.hdf5
# 12/12 [==============================] - 3s 282ms/step - loss: 0.6749 - f1_score: 0.7037 - val_loss: 2.0579 - val_f1_score: 0.2253 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5464 - f1_score: 0.7717
# Epoch 3: val_f1_score did not improve from 0.22532
# 12/12 [==============================] - 3s 274ms/step - loss: 0.5464 - f1_score: 0.7717 - val_loss: 2.3162 - val_f1_score: 0.1696 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4618 - f1_score: 0.8091
# Epoch 4: val_f1_score did not improve from 0.22532
# 12/12 [==============================] - 3s 273ms/step - loss: 0.4618 - f1_score: 0.8091 - val_loss: 1.9892 - val_f1_score: 0.2138 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4207 - f1_score: 0.8206
# Epoch 5: val_f1_score did not improve from 0.22532
# 12/12 [==============================] - 3s 268ms/step - loss: 0.4207 - f1_score: 0.8206 - val_loss: 2.3866 - val_f1_score: 0.2217 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3209 - f1_score: 0.8689
# Epoch 6: val_f1_score did not improve from 0.22532
# 12/12 [==============================] - 3s 270ms/step - loss: 0.3209 - f1_score: 0.8689 - val_loss: 2.1574 - val_f1_score: 0.1664 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2811 - f1_score: 0.8615
# Epoch 7: val_f1_score did not improve from 0.22532
# 12/12 [==============================] - 3s 266ms/step - loss: 0.2811 - f1_score: 0.8615 - val_loss: 1.9951 - val_f1_score: 0.1696 - lr: 5.0000e-04
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3248 - f1_score: 0.8709
# Epoch 8: val_f1_score did not improve from 0.22532
# 12/12 [==============================] - 3s 265ms/step - loss: 0.3248 - f1_score: 0.8709 - val_loss: 1.8273 - val_f1_score: 0.2233 - lr: 5.0000e-04
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2688 - f1_score: 0.8808
# Epoch 9: val_f1_score improved from 0.22532 to 0.22981, saving model to weights-improvement-09-0.23.hdf5
# 12/12 [==============================] - 4s 349ms/step - loss: 0.2688 - f1_score: 0.8808 - val_loss: 1.6579 - val_f1_score: 0.2298 - lr: 5.0000e-04
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2811 - f1_score: 0.8956
# Epoch 10: val_f1_score did not improve from 0.22981
# 12/12 [==============================] - 3s 273ms/step - loss: 0.2811 - f1_score: 0.8956 - val_loss: 1.5085 - val_f1_score: 0.2249 - lr: 5.0000e-04
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2578 - f1_score: 0.8933
# Epoch 11: val_f1_score improved from 0.22981 to 0.28128, saving model to weights-improvement-11-0.28.hdf5
# 12/12 [==============================] - 3s 278ms/step - loss: 0.2578 - f1_score: 0.8933 - val_loss: 1.3707 - val_f1_score: 0.2813 - lr: 5.0000e-04
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2516 - f1_score: 0.8942
# Epoch 12: val_f1_score improved from 0.28128 to 0.34378, saving model to weights-improvement-12-0.34.hdf5
# 12/12 [==============================] - 4s 291ms/step - loss: 0.2516 - f1_score: 0.8942 - val_loss: 1.2535 - val_f1_score: 0.3438 - lr: 5.0000e-04
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2444 - f1_score: 0.8921
# Epoch 13: val_f1_score improved from 0.34378 to 0.34620, saving model to weights-improvement-13-0.35.hdf5
# 12/12 [==============================] - 4s 290ms/step - loss: 0.2444 - f1_score: 0.8921 - val_loss: 1.1383 - val_f1_score: 0.3462 - lr: 5.0000e-04
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2645 - f1_score: 0.9096
# Epoch 14: val_f1_score improved from 0.34620 to 0.36267, saving model to weights-improvement-14-0.36.hdf5
# 12/12 [==============================] - 4s 288ms/step - loss: 0.2645 - f1_score: 0.9096 - val_loss: 1.0374 - val_f1_score: 0.3627 - lr: 5.0000e-04
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2637 - f1_score: 0.8889
# Epoch 15: val_f1_score improved from 0.36267 to 0.41614, saving model to weights-improvement-15-0.42.hdf5
# 12/12 [==============================] - 3s 297ms/step - loss: 0.2637 - f1_score: 0.8889 - val_loss: 0.9614 - val_f1_score: 0.4161 - lr: 5.0000e-04
# NFold 3 Validation loss: [1.8531367778778076, 2.0579354763031006, 2.316199779510498, 1.9891588687896729, 2.3865556716918945, 2.1574108600616455, 1.9951008558273315, 1.8272558450698853, 1.6579291820526123, 1.508465051651001, 1.3706780672073364, 1.2535476684570312, 1.138306736946106, 1.0373969078063965, 0.9614027142524719, 1.700698697566986] / Validation f-score: [0.17445054650306702, 0.22532466053962708, 0.1696428507566452, 0.21375197172164917, 0.22171051800251007, 0.16635337471961975, 0.1696428507566452, 0.22331932187080383, 0.2298128455877304, 0.22487212717533112, 0.28127631545066833, 0.34377628564834595, 0.34619563817977905, 0.3626748323440552, 0.41613635420799255]
# 2/2 [==============================] - 0s 82ms/step - loss: 0.9614 - f1_score: 0.4161
# Trial 2 Test loss: 0.9614025354385376 / Test accuracy: 0.41613635420799255
#
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_12 (Flatten)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 256)               131328
#
#  batch_normalization_12 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.3197 - f1_score: 0.4371
# Epoch 1: val_f1_score improved from -inf to 0.18214, saving model to weights-improvement-01-0.18.hdf5
# 12/12 [==============================] - 5s 322ms/step - loss: 1.3197 - f1_score: 0.4371 - val_loss: 1.6967 - val_f1_score: 0.1821 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6812 - f1_score: 0.6909
# Epoch 2: val_f1_score did not improve from 0.18214
# 12/12 [==============================] - 3s 272ms/step - loss: 0.6812 - f1_score: 0.6909 - val_loss: 1.7109 - val_f1_score: 0.1304 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5192 - f1_score: 0.7812
# Epoch 3: val_f1_score improved from 0.18214 to 0.27881, saving model to weights-improvement-03-0.28.hdf5
# 12/12 [==============================] - 3s 295ms/step - loss: 0.5192 - f1_score: 0.7812 - val_loss: 1.2421 - val_f1_score: 0.2788 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4082 - f1_score: 0.8356
# Epoch 4: val_f1_score did not improve from 0.27881
# 12/12 [==============================] - 3s 271ms/step - loss: 0.4082 - f1_score: 0.8356 - val_loss: 1.3622 - val_f1_score: 0.2729 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3286 - f1_score: 0.8788
# Epoch 5: val_f1_score did not improve from 0.27881
# 12/12 [==============================] - 3s 269ms/step - loss: 0.3286 - f1_score: 0.8788 - val_loss: 1.3465 - val_f1_score: 0.2267 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3170 - f1_score: 0.8608
# Epoch 6: val_f1_score improved from 0.27881 to 0.29276, saving model to weights-improvement-06-0.29.hdf5
# 12/12 [==============================] - 4s 290ms/step - loss: 0.3170 - f1_score: 0.8608 - val_loss: 1.2678 - val_f1_score: 0.2928 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3023 - f1_score: 0.8705
# Epoch 7: val_f1_score improved from 0.29276 to 0.31931, saving model to weights-improvement-07-0.32.hdf5
# 12/12 [==============================] - 4s 287ms/step - loss: 0.3023 - f1_score: 0.8705 - val_loss: 1.0350 - val_f1_score: 0.3193 - lr: 0.0100
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2434 - f1_score: 0.9025
# Epoch 8: val_f1_score improved from 0.31931 to 0.36519, saving model to weights-improvement-08-0.37.hdf5
# 12/12 [==============================] - 4s 301ms/step - loss: 0.2434 - f1_score: 0.9025 - val_loss: 1.1171 - val_f1_score: 0.3652 - lr: 0.0100
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2366 - f1_score: 0.8937
# Epoch 9: val_f1_score did not improve from 0.36519
# 12/12 [==============================] - 3s 262ms/step - loss: 0.2366 - f1_score: 0.8937 - val_loss: 1.0241 - val_f1_score: 0.3478 - lr: 0.0100
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1865 - f1_score: 0.9272
# Epoch 10: val_f1_score improved from 0.36519 to 0.41789, saving model to weights-improvement-10-0.42.hdf5
# 12/12 [==============================] - 4s 285ms/step - loss: 0.1865 - f1_score: 0.9272 - val_loss: 0.9204 - val_f1_score: 0.4179 - lr: 0.0100
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1494 - f1_score: 0.9348
# Epoch 11: val_f1_score improved from 0.41789 to 0.58128, saving model to weights-improvement-11-0.58.hdf5
# 12/12 [==============================] - 4s 293ms/step - loss: 0.1494 - f1_score: 0.9348 - val_loss: 0.7584 - val_f1_score: 0.5813 - lr: 0.0100
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2166 - f1_score: 0.9123
# Epoch 12: val_f1_score did not improve from 0.58128
# 12/12 [==============================] - 3s 271ms/step - loss: 0.2166 - f1_score: 0.9123 - val_loss: 0.8008 - val_f1_score: 0.5036 - lr: 0.0100
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1430 - f1_score: 0.9449
# Epoch 13: val_f1_score did not improve from 0.58128
# 12/12 [==============================] - 3s 284ms/step - loss: 0.1430 - f1_score: 0.9449 - val_loss: 0.8800 - val_f1_score: 0.5008 - lr: 0.0100
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1606 - f1_score: 0.9445
# Epoch 14: val_f1_score improved from 0.58128 to 0.68717, saving model to weights-improvement-14-0.69.hdf5
# 12/12 [==============================] - 4s 288ms/step - loss: 0.1606 - f1_score: 0.9445 - val_loss: 0.8431 - val_f1_score: 0.6872 - lr: 0.0100
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1318 - f1_score: 0.9538
# Epoch 15: val_f1_score did not improve from 0.68717
# 12/12 [==============================] - 3s 272ms/step - loss: 0.1318 - f1_score: 0.9538 - val_loss: 0.8005 - val_f1_score: 0.6466 - lr: 0.0100
# NFold 4 Validation loss: [1.6966828107833862, 1.7109298706054688, 1.2420716285705566, 1.3621705770492554, 1.3464607000350952, 1.2677719593048096, 1.0350123643875122, 1.1171313524246216, 1.0241233110427856, 0.9203510880470276, 0.758447527885437, 0.8008429408073425, 0.8800045251846313, 0.8430615067481995, 0.8004717826843262, 1.1203689297040305] / Validation f-score: [0.18214285373687744, 0.13041958212852478, 0.2788149416446686, 0.27291667461395264, 0.2267473042011261, 0.2927631735801697, 0.3193138837814331, 0.3651871979236603, 0.3478260934352875, 0.4178868532180786, 0.5812796950340271, 0.5035713911056519, 0.5008074045181274, 0.6871710419654846, 0.6466407775878906]
# 2/2 [==============================] - 0s 84ms/step - loss: 0.8005 - f1_score: 0.6466
# Trial 3 Test loss: 0.8004716038703918 / Test accuracy: 0.6466407775878906
#
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_13 (Flatten)        (None, 512)               0
#
#  dense_26 (Dense)            (None, 256)               131328
#
#  batch_normalization_13 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_27 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.2045 - f1_score: 0.5796
# Epoch 1: val_f1_score improved from -inf to 0.05556, saving model to weights-improvement-01-0.06.hdf5
# 12/12 [==============================] - 5s 312ms/step - loss: 1.2045 - f1_score: 0.5796 - val_loss: 2.5205 - val_f1_score: 0.0556 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.8032 - f1_score: 0.6370
# Epoch 2: val_f1_score did not improve from 0.05556
# 12/12 [==============================] - 3s 271ms/step - loss: 0.8032 - f1_score: 0.6370 - val_loss: 2.6522 - val_f1_score: 0.0532 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5906 - f1_score: 0.7324
# Epoch 3: val_f1_score did not improve from 0.05556
# 12/12 [==============================] - 3s 272ms/step - loss: 0.5906 - f1_score: 0.7324 - val_loss: 2.4748 - val_f1_score: 0.0556 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4439 - f1_score: 0.7938
# Epoch 4: val_f1_score did not improve from 0.05556
# 12/12 [==============================] - 3s 273ms/step - loss: 0.4439 - f1_score: 0.7938 - val_loss: 2.4994 - val_f1_score: 0.0543 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4296 - f1_score: 0.8073
# Epoch 5: val_f1_score improved from 0.05556 to 0.16270, saving model to weights-improvement-05-0.16.hdf5
# 12/12 [==============================] - 3s 278ms/step - loss: 0.4296 - f1_score: 0.8073 - val_loss: 2.0122 - val_f1_score: 0.1627 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3276 - f1_score: 0.8766
# Epoch 6: val_f1_score improved from 0.16270 to 0.20096, saving model to weights-improvement-06-0.20.hdf5
# 12/12 [==============================] - 4s 293ms/step - loss: 0.3276 - f1_score: 0.8766 - val_loss: 1.6384 - val_f1_score: 0.2010 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3167 - f1_score: 0.8573
# Epoch 7: val_f1_score improved from 0.20096 to 0.25388, saving model to weights-improvement-07-0.25.hdf5
# 12/12 [==============================] - 3s 277ms/step - loss: 0.3167 - f1_score: 0.8573 - val_loss: 1.2892 - val_f1_score: 0.2539 - lr: 0.0100
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2735 - f1_score: 0.8864
# Epoch 8: val_f1_score improved from 0.25388 to 0.35877, saving model to weights-improvement-08-0.36.hdf5
# 12/12 [==============================] - 3s 306ms/step - loss: 0.2735 - f1_score: 0.8864 - val_loss: 1.2089 - val_f1_score: 0.3588 - lr: 0.0100
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2314 - f1_score: 0.9120
# Epoch 9: val_f1_score improved from 0.35877 to 0.51878, saving model to weights-improvement-09-0.52.hdf5
# 12/12 [==============================] - 3s 279ms/step - loss: 0.2314 - f1_score: 0.9120 - val_loss: 0.9745 - val_f1_score: 0.5188 - lr: 0.0100
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2139 - f1_score: 0.9050
# Epoch 10: val_f1_score improved from 0.51878 to 0.53568, saving model to weights-improvement-10-0.54.hdf5
# 12/12 [==============================] - 3s 277ms/step - loss: 0.2139 - f1_score: 0.9050 - val_loss: 0.9485 - val_f1_score: 0.5357 - lr: 0.0100
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2457 - f1_score: 0.9064
# Epoch 11: val_f1_score improved from 0.53568 to 0.56339, saving model to weights-improvement-11-0.56.hdf5
# 12/12 [==============================] - 4s 298ms/step - loss: 0.2457 - f1_score: 0.9064 - val_loss: 0.8742 - val_f1_score: 0.5634 - lr: 0.0100
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1808 - f1_score: 0.9340
# Epoch 12: val_f1_score improved from 0.56339 to 0.62278, saving model to weights-improvement-12-0.62.hdf5
# 12/12 [==============================] - 4s 285ms/step - loss: 0.1808 - f1_score: 0.9340 - val_loss: 0.8371 - val_f1_score: 0.6228 - lr: 0.0100
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1953 - f1_score: 0.9312
# Epoch 13: val_f1_score did not improve from 0.62278
# 12/12 [==============================] - 3s 269ms/step - loss: 0.1953 - f1_score: 0.9312 - val_loss: 1.1397 - val_f1_score: 0.3898 - lr: 0.0100
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1798 - f1_score: 0.9428
# Epoch 14: val_f1_score did not improve from 0.62278
# 12/12 [==============================] - 3s 269ms/step - loss: 0.1798 - f1_score: 0.9428 - val_loss: 1.2662 - val_f1_score: 0.4565 - lr: 0.0100
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1580 - f1_score: 0.9412
# Epoch 15: val_f1_score did not improve from 0.62278
# 12/12 [==============================] - 3s 275ms/step - loss: 0.1580 - f1_score: 0.9412 - val_loss: 1.0581 - val_f1_score: 0.5675 - lr: 0.0100
# NFold 5 Validation loss: [2.5204784870147705, 2.652186632156372, 2.474816083908081, 2.499433994293213, 2.0122129917144775, 1.638411045074463, 1.2891991138458252, 1.2089165449142456, 0.9745193123817444, 0.9485028982162476, 0.8742496371269226, 0.8370955586433411, 1.1396875381469727, 1.2661689519882202, 1.0580867528915405, 1.5595977028210959] / Validation f-score: [0.055555559694767, 0.05319149047136307, 0.055555559694767, 0.05434782803058624, 0.1626984179019928, 0.20096153020858765, 0.25388258695602417, 0.3587701916694641, 0.5187796950340271, 0.535679280757904, 0.5633928775787354, 0.6227829456329346, 0.38982683420181274, 0.4564799666404724, 0.5674985647201538]
# 2/2 [==============================] - 0s 81ms/step - loss: 1.0581 - f1_score: 0.5675
# Trial 4 Test loss: 1.0580867528915405 / Test accuracy: 0.5674985647201538
#
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_14 (Flatten)        (None, 512)               0
#
#  dense_28 (Dense)            (None, 256)               131328
#
#  batch_normalization_14 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.1977 - f1_score: 0.5138
# Epoch 1: val_f1_score improved from -inf to 0.15972, saving model to weights-improvement-01-0.16.hdf5
# 12/12 [==============================] - 5s 317ms/step - loss: 1.1977 - f1_score: 0.5138 - val_loss: 1.4227 - val_f1_score: 0.1597 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.7131 - f1_score: 0.6783
# Epoch 2: val_f1_score improved from 0.15972 to 0.22133, saving model to weights-improvement-02-0.22.hdf5
# 12/12 [==============================] - 4s 289ms/step - loss: 0.7131 - f1_score: 0.6783 - val_loss: 1.2799 - val_f1_score: 0.2213 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5329 - f1_score: 0.7470
# Epoch 3: val_f1_score improved from 0.22133 to 0.25497, saving model to weights-improvement-03-0.25.hdf5
# 12/12 [==============================] - 4s 297ms/step - loss: 0.5329 - f1_score: 0.7470 - val_loss: 1.3518 - val_f1_score: 0.2550 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4795 - f1_score: 0.7755
# Epoch 4: val_f1_score improved from 0.25497 to 0.40923, saving model to weights-improvement-04-0.41.hdf5
# 12/12 [==============================] - 4s 285ms/step - loss: 0.4795 - f1_score: 0.7755 - val_loss: 1.1199 - val_f1_score: 0.4092 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4368 - f1_score: 0.8202
# Epoch 5: val_f1_score did not improve from 0.40923
# 12/12 [==============================] - 3s 266ms/step - loss: 0.4368 - f1_score: 0.8202 - val_loss: 1.1981 - val_f1_score: 0.2981 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3896 - f1_score: 0.8299
# Epoch 6: val_f1_score did not improve from 0.40923
# 12/12 [==============================] - 3s 275ms/step - loss: 0.3896 - f1_score: 0.8299 - val_loss: 1.0728 - val_f1_score: 0.4077 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3173 - f1_score: 0.8749
# Epoch 7: val_f1_score did not improve from 0.40923
# 12/12 [==============================] - 3s 270ms/step - loss: 0.3173 - f1_score: 0.8749 - val_loss: 1.1405 - val_f1_score: 0.3059 - lr: 0.0100
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2716 - f1_score: 0.9065
# Epoch 8: val_f1_score did not improve from 0.40923
# 12/12 [==============================] - 3s 270ms/step - loss: 0.2716 - f1_score: 0.9065 - val_loss: 1.1336 - val_f1_score: 0.3277 - lr: 0.0100
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2251 - f1_score: 0.9138
# Epoch 9: val_f1_score improved from 0.40923 to 0.45089, saving model to weights-improvement-09-0.45.hdf5
# 12/12 [==============================] - 4s 297ms/step - loss: 0.2251 - f1_score: 0.9138 - val_loss: 1.0772 - val_f1_score: 0.4509 - lr: 0.0100
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2151 - f1_score: 0.9110
# Epoch 10: val_f1_score did not improve from 0.45089
# 12/12 [==============================] - 4s 284ms/step - loss: 0.2151 - f1_score: 0.9110 - val_loss: 1.3475 - val_f1_score: 0.3604 - lr: 0.0100
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1790 - f1_score: 0.9231
# Epoch 11: val_f1_score improved from 0.45089 to 0.46078, saving model to weights-improvement-11-0.46.hdf5
# 12/12 [==============================] - 4s 285ms/step - loss: 0.1790 - f1_score: 0.9231 - val_loss: 0.9693 - val_f1_score: 0.4608 - lr: 0.0100
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1339 - f1_score: 0.9567
# Epoch 12: val_f1_score improved from 0.46078 to 0.62606, saving model to weights-improvement-12-0.63.hdf5
# 12/12 [==============================] - 3s 295ms/step - loss: 0.1339 - f1_score: 0.9567 - val_loss: 0.8420 - val_f1_score: 0.6261 - lr: 0.0100
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1682 - f1_score: 0.9386
# Epoch 13: val_f1_score did not improve from 0.62606
# 12/12 [==============================] - 4s 284ms/step - loss: 0.1682 - f1_score: 0.9386 - val_loss: 0.9235 - val_f1_score: 0.5250 - lr: 0.0100
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1513 - f1_score: 0.9467
# Epoch 14: val_f1_score improved from 0.62606 to 0.64911, saving model to weights-improvement-14-0.65.hdf5
# 12/12 [==============================] - 4s 287ms/step - loss: 0.1513 - f1_score: 0.9467 - val_loss: 0.7311 - val_f1_score: 0.6491 - lr: 0.0100
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1395 - f1_score: 0.9477
# Epoch 15: val_f1_score did not improve from 0.64911
# 12/12 [==============================] - 3s 273ms/step - loss: 0.1395 - f1_score: 0.9477 - val_loss: 0.7762 - val_f1_score: 0.5560 - lr: 0.0100
# NFold 6 Validation loss: [1.4226531982421875, 1.2798916101455688, 1.3517974615097046, 1.119877576828003, 1.1981202363967896, 1.0727709531784058, 1.1404997110366821, 1.1335718631744385, 1.0771554708480835, 1.3475407361984253, 0.9692609906196594, 0.842039167881012, 0.9235317707061768, 0.7310733795166016, 0.7761805653572083, 1.092397646109263] / Validation f-score: [0.1597222238779068, 0.22132867574691772, 0.25496894121170044, 0.4092261791229248, 0.2980895936489105, 0.4076923131942749, 0.30587121844291687, 0.3276785612106323, 0.4508928656578064, 0.3604166805744171, 0.46077901124954224, 0.6260567903518677, 0.525029718875885, 0.6491071581840515, 0.5559974908828735]
# 2/2 [==============================] - 0s 85ms/step - loss: 0.7762 - f1_score: 0.5560
# Trial 5 Test loss: 0.7761803865432739 / Test accuracy: 0.5559974908828735
#
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_15 (Flatten)        (None, 512)               0
#
#  dense_30 (Dense)            (None, 256)               131328
#
#  batch_normalization_15 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.3432 - f1_score: 0.4990
# Epoch 1: val_f1_score improved from -inf to 0.08333, saving model to weights-improvement-01-0.08.hdf5
# 12/12 [==============================] - 5s 314ms/step - loss: 1.3432 - f1_score: 0.4990 - val_loss: 1.7179 - val_f1_score: 0.0833 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6926 - f1_score: 0.7154
# Epoch 2: val_f1_score improved from 0.08333 to 0.18654, saving model to weights-improvement-02-0.19.hdf5
# 12/12 [==============================] - 3s 273ms/step - loss: 0.6926 - f1_score: 0.7154 - val_loss: 1.7946 - val_f1_score: 0.1865 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4974 - f1_score: 0.7784
# Epoch 3: val_f1_score did not improve from 0.18654
# 12/12 [==============================] - 3s 263ms/step - loss: 0.4974 - f1_score: 0.7784 - val_loss: 1.9326 - val_f1_score: 0.1765 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4280 - f1_score: 0.8208
# Epoch 4: val_f1_score improved from 0.18654 to 0.20248, saving model to weights-improvement-04-0.20.hdf5
# 12/12 [==============================] - 4s 286ms/step - loss: 0.4280 - f1_score: 0.8208 - val_loss: 1.7049 - val_f1_score: 0.2025 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3640 - f1_score: 0.8609
# Epoch 5: val_f1_score improved from 0.20248 to 0.22374, saving model to weights-improvement-05-0.22.hdf5
# 12/12 [==============================] - 3s 276ms/step - loss: 0.3640 - f1_score: 0.8609 - val_loss: 1.6707 - val_f1_score: 0.2237 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3331 - f1_score: 0.8508
# Epoch 6: val_f1_score did not improve from 0.22374
# 12/12 [==============================] - 3s 268ms/step - loss: 0.3331 - f1_score: 0.8508 - val_loss: 1.4502 - val_f1_score: 0.2237 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2824 - f1_score: 0.8960
# Epoch 7: val_f1_score improved from 0.22374 to 0.27949, saving model to weights-improvement-07-0.28.hdf5
# 12/12 [==============================] - 3s 276ms/step - loss: 0.2824 - f1_score: 0.8960 - val_loss: 1.2243 - val_f1_score: 0.2795 - lr: 0.0100
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2867 - f1_score: 0.8923
# Epoch 8: val_f1_score did not improve from 0.27949
# 12/12 [==============================] - 3s 270ms/step - loss: 0.2867 - f1_score: 0.8923 - val_loss: 1.2731 - val_f1_score: 0.2795 - lr: 0.0100
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2520 - f1_score: 0.9099
# Epoch 9: val_f1_score improved from 0.27949 to 0.28615, saving model to weights-improvement-09-0.29.hdf5
# 12/12 [==============================] - 3s 279ms/step - loss: 0.2520 - f1_score: 0.9099 - val_loss: 1.1247 - val_f1_score: 0.2862 - lr: 0.0100
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1809 - f1_score: 0.9315
# Epoch 10: val_f1_score improved from 0.28615 to 0.29081, saving model to weights-improvement-10-0.29.hdf5
# 12/12 [==============================] - 4s 282ms/step - loss: 0.1809 - f1_score: 0.9315 - val_loss: 1.2461 - val_f1_score: 0.2908 - lr: 0.0100
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1534 - f1_score: 0.9391
# Epoch 11: val_f1_score improved from 0.29081 to 0.29179, saving model to weights-improvement-11-0.29.hdf5
# 12/12 [==============================] - 3s 276ms/step - loss: 0.1534 - f1_score: 0.9391 - val_loss: 1.3649 - val_f1_score: 0.2918 - lr: 0.0100
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1723 - f1_score: 0.9285
# Epoch 12: val_f1_score improved from 0.29179 to 0.43512, saving model to weights-improvement-12-0.44.hdf5
# 12/12 [==============================] - 4s 287ms/step - loss: 0.1723 - f1_score: 0.9285 - val_loss: 1.2558 - val_f1_score: 0.4351 - lr: 0.0100
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1839 - f1_score: 0.9332
# Epoch 13: val_f1_score did not improve from 0.43512
# 12/12 [==============================] - 3s 274ms/step - loss: 0.1839 - f1_score: 0.9332 - val_loss: 1.2867 - val_f1_score: 0.4045 - lr: 0.0100
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1435 - f1_score: 0.9473
# Epoch 14: val_f1_score improved from 0.43512 to 0.59309, saving model to weights-improvement-14-0.59.hdf5
# 12/12 [==============================] - 3s 273ms/step - loss: 0.1435 - f1_score: 0.9473 - val_loss: 0.8731 - val_f1_score: 0.5931 - lr: 0.0100
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1384 - f1_score: 0.9432
# Epoch 15: val_f1_score did not improve from 0.59309
# 12/12 [==============================] - 3s 269ms/step - loss: 0.1384 - f1_score: 0.9432 - val_loss: 0.9220 - val_f1_score: 0.5556 - lr: 0.0100
# NFold 7 Validation loss: [1.7179020643234253, 1.794567584991455, 1.9325814247131348, 1.704904556274414, 1.6706684827804565, 1.4502347707748413, 1.2243298292160034, 1.2730532884597778, 1.1247128248214722, 1.246112585067749, 1.3648531436920166, 1.25580632686615, 1.2866847515106201, 0.8730975985527039, 0.9219985604286194, 1.3894338528315227] / Validation f-score: [0.0833333358168602, 0.1865384578704834, 0.1765109896659851, 0.20247679948806763, 0.22374005615711212, 0.22374005615711212, 0.2794871926307678, 0.2794871926307678, 0.2861538529396057, 0.2908121645450592, 0.29178571701049805, 0.43511903285980225, 0.4044871926307678, 0.5930861234664917, 0.5555860996246338]
# 2/2 [==============================] - 0s 85ms/step - loss: 0.9220 - f1_score: 0.5556
# Trial 6 Test loss: 0.9219985604286194 / Test accuracy: 0.5555860996246338
#
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_16 (Flatten)        (None, 512)               0
#
#  dense_32 (Dense)            (None, 256)               131328
#
#  batch_normalization_16 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_33 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.3607 - f1_score: 0.4630
# Epoch 1: val_f1_score improved from -inf to 0.21825, saving model to weights-improvement-01-0.22.hdf5
# 12/12 [==============================] - 5s 308ms/step - loss: 1.3607 - f1_score: 0.4630 - val_loss: 1.6139 - val_f1_score: 0.2183 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6510 - f1_score: 0.7397
# Epoch 2: val_f1_score did not improve from 0.21825
# 12/12 [==============================] - 3s 272ms/step - loss: 0.6510 - f1_score: 0.7397 - val_loss: 1.8683 - val_f1_score: 0.0581 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4907 - f1_score: 0.8114
# Epoch 3: val_f1_score did not improve from 0.21825
# 12/12 [==============================] - 3s 273ms/step - loss: 0.4907 - f1_score: 0.8114 - val_loss: 1.5395 - val_f1_score: 0.1526 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5099 - f1_score: 0.7837
# Epoch 4: val_f1_score did not improve from 0.21825
# 12/12 [==============================] - 3s 260ms/step - loss: 0.5099 - f1_score: 0.7837 - val_loss: 1.9132 - val_f1_score: 0.0568 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3786 - f1_score: 0.8316
# Epoch 5: val_f1_score did not improve from 0.21825
# 12/12 [==============================] - 3s 264ms/step - loss: 0.3786 - f1_score: 0.8316 - val_loss: 1.8985 - val_f1_score: 0.1290 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3613 - f1_score: 0.8592
# Epoch 6: val_f1_score did not improve from 0.21825
# 12/12 [==============================] - 3s 271ms/step - loss: 0.3613 - f1_score: 0.8592 - val_loss: 1.7727 - val_f1_score: 0.1068 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2871 - f1_score: 0.8638
# Epoch 7: val_f1_score did not improve from 0.21825
# 12/12 [==============================] - 3s 267ms/step - loss: 0.2871 - f1_score: 0.8638 - val_loss: 1.5691 - val_f1_score: 0.1929 - lr: 0.0100
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2855 - f1_score: 0.9059
# Epoch 8: val_f1_score did not improve from 0.21825
# 12/12 [==============================] - 3s 275ms/step - loss: 0.2855 - f1_score: 0.9059 - val_loss: 1.3992 - val_f1_score: 0.1974 - lr: 0.0100
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2206 - f1_score: 0.9197
# Epoch 9: val_f1_score improved from 0.21825 to 0.31181, saving model to weights-improvement-09-0.31.hdf5
# 12/12 [==============================] - 3s 274ms/step - loss: 0.2206 - f1_score: 0.9197 - val_loss: 1.3775 - val_f1_score: 0.3118 - lr: 0.0100
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2022 - f1_score: 0.9223
# Epoch 10: val_f1_score improved from 0.31181 to 0.35210, saving model to weights-improvement-10-0.35.hdf5
# 12/12 [==============================] - 3s 297ms/step - loss: 0.2022 - f1_score: 0.9223 - val_loss: 1.1874 - val_f1_score: 0.3521 - lr: 0.0100
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1769 - f1_score: 0.9377
# ...
#
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_106"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_106 (Flatten)       (None, 512)               0
#
#  dense_212 (Dense)           (None, 256)               131328
#
#  batch_normalization_106 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_106 (Dropout)       (None, 256)               0
#
#  dense_213 (Dense)           (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.3484 - f1_score: 0.4851
# Epoch 1: val_f1_score improved from -inf to 0.19048, saving model to weights-improvement-01-0.19.hdf5
# 12/12 [==============================] - 5s 331ms/step - loss: 1.3484 - f1_score: 0.4851 - val_loss: 1.6050 - val_f1_score: 0.1905 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6742 - f1_score: 0.7142
# Epoch 2: val_f1_score did not improve from 0.19048
# 12/12 [==============================] - 3s 270ms/step - loss: 0.6742 - f1_score: 0.7142 - val_loss: 1.7986 - val_f1_score: 0.1562 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5012 - f1_score: 0.7627
# Epoch 3: val_f1_score did not improve from 0.19048
# 12/12 [==============================] - 3s 270ms/step - loss: 0.5012 - f1_score: 0.7627 - val_loss: 2.0448 - val_f1_score: 0.1202 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4135 - f1_score: 0.8200
# Epoch 4: val_f1_score did not improve from 0.19048
# 12/12 [==============================] - 3s 270ms/step - loss: 0.4135 - f1_score: 0.8200 - val_loss: 1.8168 - val_f1_score: 0.1776 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4052 - f1_score: 0.8249
# Epoch 5: val_f1_score did not improve from 0.19048
# 12/12 [==============================] - 3s 274ms/step - loss: 0.4052 - f1_score: 0.8249 - val_loss: 1.8810 - val_f1_score: 0.1202 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2564 - f1_score: 0.8877
# Epoch 6: val_f1_score did not improve from 0.19048
# 12/12 [==============================] - 3s 273ms/step - loss: 0.2564 - f1_score: 0.8877 - val_loss: 2.1235 - val_f1_score: 0.1214 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2698 - f1_score: 0.8886
# Epoch 7: val_f1_score did not improve from 0.19048
# 12/12 [==============================] - 3s 272ms/step - loss: 0.2698 - f1_score: 0.8886 - val_loss: 1.8851 - val_f1_score: 0.1226 - lr: 5.0000e-04
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3112 - f1_score: 0.8667
# Epoch 8: val_f1_score did not improve from 0.19048
# 12/12 [==============================] - 3s 290ms/step - loss: 0.3112 - f1_score: 0.8667 - val_loss: 1.6645 - val_f1_score: 0.1202 - lr: 5.0000e-04
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2748 - f1_score: 0.8969
# Epoch 9: val_f1_score did not improve from 0.19048
# 12/12 [==============================] - 3s 278ms/step - loss: 0.2748 - f1_score: 0.8969 - val_loss: 1.4787 - val_f1_score: 0.1259 - lr: 5.0000e-04
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2522 - f1_score: 0.8921
# Epoch 10: val_f1_score improved from 0.19048 to 0.19241, saving model to weights-improvement-10-0.19.hdf5
# 12/12 [==============================] - 4s 286ms/step - loss: 0.2522 - f1_score: 0.8921 - val_loss: 1.3202 - val_f1_score: 0.1924 - lr: 5.0000e-04
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2488 - f1_score: 0.8994
# Epoch 11: val_f1_score improved from 0.19241 to 0.27790, saving model to weights-improvement-11-0.28.hdf5
# 12/12 [==============================] - 4s 295ms/step - loss: 0.2488 - f1_score: 0.8994 - val_loss: 1.1786 - val_f1_score: 0.2779 - lr: 5.0000e-04
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2921 - f1_score: 0.8808
# Epoch 12: val_f1_score improved from 0.27790 to 0.29535, saving model to weights-improvement-12-0.30.hdf5
# 12/12 [==============================] - 4s 292ms/step - loss: 0.2921 - f1_score: 0.8808 - val_loss: 1.0417 - val_f1_score: 0.2953 - lr: 5.0000e-04
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2498 - f1_score: 0.9059
# Epoch 13: val_f1_score improved from 0.29535 to 0.40785, saving model to weights-improvement-13-0.41.hdf5
# 12/12 [==============================] - 4s 283ms/step - loss: 0.2498 - f1_score: 0.9059 - val_loss: 0.9252 - val_f1_score: 0.4078 - lr: 5.0000e-04
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2538 - f1_score: 0.8904
# Epoch 14: val_f1_score improved from 0.40785 to 0.46786, saving model to weights-improvement-14-0.47.hdf5
# 12/12 [==============================] - 4s 283ms/step - loss: 0.2538 - f1_score: 0.8904 - val_loss: 0.8316 - val_f1_score: 0.4679 - lr: 5.0000e-04
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2332 - f1_score: 0.9197
# Epoch 15: val_f1_score did not improve from 0.46786
# 12/12 [==============================] - 3s 280ms/step - loss: 0.2332 - f1_score: 0.9197 - val_loss: 0.7530 - val_f1_score: 0.4615 - lr: 5.0000e-04
# NFold 8 Validation loss: [1.604997158050537, 1.7985860109329224, 2.044813632965088, 1.8168234825134277, 1.8809986114501953, 2.123506546020508, 1.8850888013839722, 1.6644595861434937, 1.4787163734436035, 1.3201940059661865, 1.178599238395691, 1.0417160987854004, 0.9251962900161743, 0.831592857837677, 0.7529786825180054, 1.4898844917615255] / Validation f-score: [0.1904761791229248, 0.15625, 0.12023810297250748, 0.17758621275424957, 0.12023810297250748, 0.12142857909202576, 0.12256494164466858, 0.12023810297250748, 0.12587720155715942, 0.19241072237491608, 0.27790403366088867, 0.2953493595123291, 0.40784937143325806, 0.46785712242126465, 0.4615384638309479]
# 2/2 [==============================] - 0s 89ms/step - loss: 0.7530 - f1_score: 0.4615
# Trial 97 Test loss: 0.7529786229133606 / Test accuracy: 0.4615384638309479
#
# Found 362 validated image filenames belonging to 8 classes.
# Found 41 validated image filenames belonging to 8 classes.
# Model: "sequential_107"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_107 (Flatten)       (None, 512)               0
#
#  dense_214 (Dense)           (None, 256)               131328
#
#  batch_normalization_107 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_107 (Dropout)       (None, 256)               0
#
#  dense_215 (Dense)           (None, 8)                 2056
#
# =================================================================
# Total params: 14,849,096
# Trainable params: 133,896
# Non-trainable params: 14,715,200
# _________________________________________________________________
# None
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 1.2508 - f1_score: 0.5152
# Epoch 1: val_f1_score improved from -inf to 0.07164, saving model to weights-improvement-01-0.07.hdf5
# 12/12 [==============================] - 5s 316ms/step - loss: 1.2508 - f1_score: 0.5152 - val_loss: 2.0448 - val_f1_score: 0.0716 - lr: 0.0100
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6655 - f1_score: 0.7136
# Epoch 2: val_f1_score improved from 0.07164 to 0.12256, saving model to weights-improvement-02-0.12.hdf5
# 12/12 [==============================] - 4s 287ms/step - loss: 0.6655 - f1_score: 0.7136 - val_loss: 2.0978 - val_f1_score: 0.1226 - lr: 0.0100
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4900 - f1_score: 0.7787
# Epoch 3: val_f1_score improved from 0.12256 to 0.24821, saving model to weights-improvement-03-0.25.hdf5
# 12/12 [==============================] - 4s 291ms/step - loss: 0.4900 - f1_score: 0.7787 - val_loss: 1.2864 - val_f1_score: 0.2482 - lr: 0.0100
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.4290 - f1_score: 0.8000
# Epoch 4: val_f1_score improved from 0.24821 to 0.32144, saving model to weights-improvement-04-0.32.hdf5
# 12/12 [==============================] - 4s 293ms/step - loss: 0.4290 - f1_score: 0.8000 - val_loss: 1.2499 - val_f1_score: 0.3214 - lr: 0.0100
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3620 - f1_score: 0.8255
# Epoch 5: val_f1_score did not improve from 0.32144
# 12/12 [==============================] - 3s 279ms/step - loss: 0.3620 - f1_score: 0.8255 - val_loss: 1.2029 - val_f1_score: 0.2651 - lr: 0.0100
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3734 - f1_score: 0.8223
# Epoch 6: val_f1_score did not improve from 0.32144
# 12/12 [==============================] - 3s 277ms/step - loss: 0.3734 - f1_score: 0.8223 - val_loss: 1.3651 - val_f1_score: 0.2781 - lr: 0.0100
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3262 - f1_score: 0.8548
# Epoch 7: val_f1_score did not improve from 0.32144
# 12/12 [==============================] - 3s 277ms/step - loss: 0.3262 - f1_score: 0.8548 - val_loss: 1.6700 - val_f1_score: 0.2007 - lr: 0.0100
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2638 - f1_score: 0.8787
# Epoch 8: val_f1_score improved from 0.32144 to 0.32656, saving model to weights-improvement-08-0.33.hdf5
# 12/12 [==============================] - 4s 289ms/step - loss: 0.2638 - f1_score: 0.8787 - val_loss: 1.3038 - val_f1_score: 0.3266 - lr: 0.0100
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2503 - f1_score: 0.8586
# Epoch 9: val_f1_score did not improve from 0.32656
# 12/12 [==============================] - 3s 280ms/step - loss: 0.2503 - f1_score: 0.8586 - val_loss: 1.4326 - val_f1_score: 0.2514 - lr: 0.0100
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2436 - f1_score: 0.9023
# Epoch 10: val_f1_score did not improve from 0.32656
# 12/12 [==============================] - 4s 285ms/step - loss: 0.2436 - f1_score: 0.9023 - val_loss: 1.2846 - val_f1_score: 0.3265 - lr: 0.0100
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2278 - f1_score: 0.9201
# Epoch 11: val_f1_score improved from 0.32656 to 0.41488, saving model to weights-improvement-11-0.41.hdf5
# 12/12 [==============================] - 4s 296ms/step - loss: 0.2278 - f1_score: 0.9201 - val_loss: 1.1863 - val_f1_score: 0.4149 - lr: 5.0000e-04
# Epoch 12/15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6f04948d62ca> in <module>()
#      91                          batch_size=batch_size,
#      92                          validation_data=validation_generator,
# ---> 93                          callbacks=callbacklist
#      94                          )
#      95
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:
